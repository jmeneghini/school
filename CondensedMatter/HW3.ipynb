# %%
import numpy as np
import matplotlib.pyplot as plt
from sympy import *

# %% [markdown]
# 1. a) Begin by sketching the rectified sine wave function $f (x) = | \sin x|$ over the interval $−\pi < x < \pi$.
# When calculating Fourier Series, it is always a good idea to start with a sketch of the function.

# %%
x_n = np.linspace(-np.pi, np.pi, 1000)

# %%
plt.plot(x_n, np.abs(np.sin(x_n)))

# %% [markdown]
# c) Find the Fourier series for $f (x)$.

# %%
x = Symbol('x')
n = Symbol('n', integer=True)

# %%
f = Abs(sin(x))

# %%
fourier = fourier_series(f, (x, -pi, pi))

# %%
plot(fourier.truncate(18), (x, -pi, pi), ylim=(0, 1), xlabel='$x$', ylabel='$f(x)$')
